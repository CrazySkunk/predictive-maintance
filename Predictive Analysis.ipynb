# %% [markdown]
# <h1> Importing libraries

# %%
import pandas as pd
import seaborn as  sns
import numpy as np

# %%
data_set = pd.read_csv('/home/jamie/Notebooks/Predictive Analysis/.ipynb_checkpoints/Sensor_readings__with_temperature__light__humidity_every_5_minutes_at_8_locations__trial__2014_to_2015_.csv')
data_set.head(20)
# Out:
#                  timestamp               mac  boardtype  boardid  temp_max  \
# 0   12/15/2014 01:40:00 AM  0013a20040b4b755          1      508      21.6
# 1   12/15/2014 01:40:00 AM  0013a20040b516ed          1      505      23.2
# 2   12/15/2014 01:45:00 AM  0013a20040b516f6          1      507      21.6
# 3   12/15/2014 01:45:00 AM  0013a20040b5b318          1      502      21.3
# 4   12/15/2014 01:45:00 AM  0013a20040b315ec          1      501      22.9
# 5   12/15/2014 01:50:00 AM  0013a20040b4b755          1      508      21.3
# 6   12/15/2014 01:55:00 AM  0013a20040b516ed          1      505      23.2
# 7   12/15/2014 01:55:00 AM  0013a20040b516f6          1      507      21.6
# 8   12/15/2014 01:55:00 AM  0013a20040b5b318          1      502      21.6
# 9   12/15/2014 02:00:00 AM  0013a20040b315ec          1      501      23.5
# 10  12/15/2014 02:00:00 AM  0013a20040b4b755          1      508      21.6
# ...

# %%
data_set.tail(20)
# Out:
#                     timestamp               mac  boardtype  boardid  temp_max  \
# 56550  05/31/2015 05:50:00 AM  0013a20040b5b337          1      511      11.9
# 56551  05/31/2015 07:20:00 AM  0013a20040b5b337          1      511      12.3
# 56552  05/31/2015 07:30:00 AM  0013a20040b5b337          1      511      12.6
# 56553  06/01/2015 08:35:00 PM  0013a20040b5b337          1      511       7.1
# 56554  06/01/2015 09:05:00 PM  0013a20040b5b337          1      511       7.4
# 56555  06/01/2015 09:15:00 PM  0013a20040b5b337          1      511       7.4
# 56556  06/01/2015 09:35:00 PM  0013a20040b5b337          1      511       7.4
# 56557  06/02/2015 11:15:00 PM  0013a20040b5b337          1      511       8.7
# 56558  06/02/2015 11:25:00 PM  0013a20040b5b337          1      511       8.7
# 56559  06/03/2015 01:25:00 AM  0013a20040b5b337          1      511       8.4
# 56560  06/03/2015 04:30:00 AM  0013a20040b5b337          1      511       7.7
# ...

# %%
data_set.columns
# Out:
# Index(['timestamp', 'mac', 'boardtype', 'boardid', 'temp_max', 'temp_min',
#        'temp_avg', 'light_max', 'light_min', 'light_avg', 'humidity_min',
#        'humidity_max', 'humidity_avg', 'model', 'latitude', 'longitude',
#        'elevation', 'location', 'rowid', 'Position'],
#       dtype='object')

# %%
data_set.shape
# Out:
# (56570, 20)

# %%
data_set.describe()
# Out:
#        boardtype       boardid      temp_max      temp_min      temp_avg  \
# count    56570.0  56570.000000  56570.000000  56570.000000  56570.000000
# mean         1.0    507.918738     18.522650     18.522650     18.522650
# std          0.0      2.673337      5.498701      5.498701      5.498701
# min          1.0    501.000000      4.200000      4.200000      4.200000
# 25%          1.0    506.000000     14.800000     14.800000     14.800000
# 50%          1.0    509.000000     17.700000     17.700000     17.700000
# 75%          1.0    510.000000     21.900000     21.900000     21.900000
# max          1.0    511.000000     45.200000     45.200000     45.200000
#
#           light_max     light_min     light_avg  humidity_min  humidity_max  \
# count  56570.000000  56570.000000  56570.000000  56570.000000  56570.000000
# mean      48.674527     48.674527     48.674527     49.431043     49.431043
# std       43.973493     43.973493     43.973493     13.413633     13.413633
# ...

# %%
data_set=data_set['elevation'].fillna(37.5)
# Out:
# 0        30.10
# 1        29.91
# 2        38.79
# 3        22.57
# 4        29.96
#          ...
# 56565     3.75
# 56566     3.75
# 56567     3.75
# 56568     3.75
# 56569     3.75
# Name: elevation, Length: 56570, dtype: float64

# %%
data_set.dropna()
# Out:
# Empty DataFrame
# Columns: [timestamp, mac, boardtype, boardid, temp_max, temp_min, temp_avg, light_max, light_min, light_avg, humidity_min, humidity_max, humidity_avg, model, latitude, longitude, elevation, location, rowid, Position]
# Index: []

# %%
data_set.head(30)
# Out:
#                  timestamp               mac  boardtype  boardid  temp_max  \
# 0   12/15/2014 01:40:00 AM  0013a20040b4b755          1      508      21.6
# 1   12/15/2014 01:40:00 AM  0013a20040b516ed          1      505      23.2
# 2   12/15/2014 01:45:00 AM  0013a20040b516f6          1      507      21.6
# 3   12/15/2014 01:45:00 AM  0013a20040b5b318          1      502      21.3
# 4   12/15/2014 01:45:00 AM  0013a20040b315ec          1      501      22.9
# 5   12/15/2014 01:50:00 AM  0013a20040b4b755          1      508      21.3
# 6   12/15/2014 01:55:00 AM  0013a20040b516ed          1      505      23.2
# 7   12/15/2014 01:55:00 AM  0013a20040b516f6          1      507      21.6
# 8   12/15/2014 01:55:00 AM  0013a20040b5b318          1      502      21.6
# 9   12/15/2014 02:00:00 AM  0013a20040b315ec          1      501      23.5
# 10  12/15/2014 02:00:00 AM  0013a20040b4b755          1      508      21.6
# ...

# %%
data_set.isnull().sum()
# Out:
# timestamp           0
# mac                 0
# boardtype           0
# boardid             0
# temp_max            0
# temp_min            0
# temp_avg            0
# light_max           0
# light_min           0
# light_avg           0
# humidity_min        0
# humidity_max        0
# humidity_avg        0
# model               0
# latitude            0
# longitude           0
# location            0
# rowid               0
# Position        56570
# dtype: int64

# %%
# data_set = data_set.drop(columns=['elevation','Position'],axis=1)
data_set.head(20)
# Out:
#                  timestamp               mac  boardtype  boardid  temp_max  \
# 0   12/15/2014 01:40:00 AM  0013a20040b4b755          1      508      21.6
# 1   12/15/2014 01:40:00 AM  0013a20040b516ed          1      505      23.2
# 2   12/15/2014 01:45:00 AM  0013a20040b516f6          1      507      21.6
# 3   12/15/2014 01:45:00 AM  0013a20040b5b318          1      502      21.3
# 4   12/15/2014 01:45:00 AM  0013a20040b315ec          1      501      22.9
# 5   12/15/2014 01:50:00 AM  0013a20040b4b755          1      508      21.3
# 6   12/15/2014 01:55:00 AM  0013a20040b516ed          1      505      23.2
# 7   12/15/2014 01:55:00 AM  0013a20040b516f6          1      507      21.6
# 8   12/15/2014 01:55:00 AM  0013a20040b5b318          1      502      21.6
# 9   12/15/2014 02:00:00 AM  0013a20040b315ec          1      501      23.5
# 10  12/15/2014 02:00:00 AM  0013a20040b4b755          1      508      21.6
# ...

# %%
sns.relplot(x='temp_max',y='humidity_max',data=data_set)

# %%
sns.relplot(x='temp_max',y='temp_min',hue='humidity_max',data=data_set)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = data_set.drop(['timestamp','mac','boardid','boardtype','model','latitude','longitude','location','rowid'],axis=1)

# %%
test = data_set['temp_avg']
x_train,x_test,y_train,y_test=train_test_split(train,test,test_size=0.3,random_state=2)

# %%
regr = LinearRegression()
regr.fit(x_train,y_train)
pred = regr.predict(x_test)
pred
# Out:
# array([14.8, 17.4, 11.9, ..., 12.9, 23.2, 13.5])

# %%
regr.score(x_test,y_test)
# Out:
# 1.0
